# %% [markdown]
# # Connect google Drive
# * Data has been uploaded to google drive ,so we load the drive to have access to the data

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Importing  Libaries
# * Pandas = to load the datastet
# * matplotlib = to help with visualization of the data
# * seaboarn = to help with advanced visualization

# %%
import pandas as pd # load data
import matplotlib.pyplot as plt # visualize data
import seaborn as sns # advanced visualization of data
print("All Libaries Loaded")
# Out:
# All Libaries Loaded

# %% [markdown]
# # Load the dataset
# * dataset is loaded from the google drive and stored in variable data

# %%
data = pd.read_csv("used_cars.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %% [markdown]
# # Basic Insights on the data
# * shape = to know the size of the data in terms of rows and columns
# * columns = to see the column names
# * head / tail = to see the first 5 and last 5 data points in the data
# * describe
# * info
# * missing values = finding missing values and handling them
# * droping duplicates

# %%
# shape
data.shape
# Out:
# (4009, 12)

# %%
# columns
data.columns
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
data.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
data.tail()
# Out:
#         brand                 model  model_year      milage fuel_type  \
# 4004  Bentley  Continental GT Speed        2023     714 mi.  Gasoline
# 4005     Audi  S4 3.0T Premium Plus        2022  10,900 mi.  Gasoline
# 4006  Porsche                Taycan        2022   2,116 mi.       NaN
# 4007     Ford          F-150 Raptor        2020  33,000 mi.  Gasoline
# 4008      BMW          X3 xDrive30i        2020  43,000 mi.  Gasoline
#
#                                              engine  \
# 4004               6.0L W12 48V PDI DOHC Twin Turbo
# 4005  349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                       Electric
# 4007  450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008   248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission ext_col  int_col  \
# 4004  8-Speed Automatic with Auto-Shift   C / C  Hotspur
# 4005     Transmission w/Dual Shift Mode   Black    Black
# ...

# %%
#info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
# describe
data.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
# missing values
data.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %% [markdown]
# # Explository Data Analysis

# %% [markdown]
# ## Column by Column Analysis

# %%
data['brand'].value_counts()
# Out:
# brand
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Audi             200
# Toyota           199
# Lexus            163
# Jeep             143
# Land             130
# Nissan           116
# Cadillac         107
# GMC               91
# RAM               91
# Dodge             90
# Tesla             87
# Kia               76
# Hyundai           72
# Mazda             64
# Acura             64
# Subaru            64
# Honda             63
# Volkswagen        59
# INFINITI          59
# Lincoln           52
# Jaguar            47
# Volvo             38
# Maserati          34
# Bentley           33
# MINI              33
# Buick             30
# Chrysler          28
# Lamborghini       26
# Mitsubishi        20
# Genesis           20
# Alfa              19
# Rivian            17
# Hummer            16
# Pontiac           15
# Ferrari           12
# Rolls-Royce       11
# Aston              9
# McLaren            6
# ...

# %%
#top 5 brands
data['brand'].value_counts()[:5]
# Out:
# brand
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Name: count, dtype: int64

# %%
# model
data['model'].value_counts()
# Out:
# model
# M3 Base                    30
# F-150 XLT                  24
# Corvette Base              22
# 1500 Laramie               18
# Camaro 2SS                 17
#                            ..
# XE 25t                      1
# MC20 Base                   1
# 911 Carrera 4 Cabriolet     1
# 488 GTB Base                1
# Taycan                      1
# Name: count, Length: 1898, dtype: int64

# %%
# plot top 10 models
plt.figure(figsize=(10,5))
data['model'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Models')
plt.xlabel('Model')
plt.ylabel('Count')
plt.show()

# %%
#Model year
data['model_year'].value_counts()
# Out:
# model_year
# 2022    354
# 2021    350
# 2020    322
# 2018    315
# 2019    297
# 2016    268
# 2017    259
# 2015    228
# 2023    226
# 2014    181
# 2013    158
# 2012    141
# 2011    124
# 2008    113
# 2010    100
# 2007     98
# 2005     72
# 2009     72
# 2006     66
# 2004     60
# 2003     49
# 2001     34
# 2002     32
# 2000     17
# 1999     15
# 1998     11
# 1997      9
# 1993      9
# 1996      8
# 1994      7
# 2024      6
# 1995      6
# 1974      1
# 1992      1
# Name: count, dtype: int64

# %%
# plot of the top 10 model_year
plt.figure(figsize=(10,5))
data['model_year'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Model Year')
plt.xlabel('Model Year')
plt.ylabel('Count')
plt.show()

# %%
data.columns
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
# milage
data['milage'].value_counts()
# Out:
# milage
# 110,000 mi.    16
# 45,000 mi.     15
# 120,000 mi.    13
# 55,000 mi.     13
# 92,000 mi.     12
#                ..
# 40,900 mi.      1
# 74,150 mi.      1
# 94,448 mi.      1
# 34,967 mi.      1
# 2,116 mi.       1
# Name: count, Length: 2818, dtype: int64

# %%
# plot top 20 milage
plt.figure(figsize=(10,5))
data['milage'].value_counts()[:20].plot(kind='bar')
plt.title('Plot of the Top 20 Milage')
plt.xlabel('Milage')
plt.ylabel('Count')
plt.show()

# %%
# fuel_type
data['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# –                   45
# Plug-In Hybrid      34
# not supported        2
# Name: count, dtype: int64

# %%
# plot of fuel Type
plt.figure(figsize=(10,5))
sns.countplot(data['fuel_type'])
plt.title('Plot of the Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.show()
#

# %%
# engine
data['engine'].value_counts()
# Out:
# engine
# 2.0L I4 16V GDI DOHC Turbo                               52
# 355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel             48
# 420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel             47
# –                                                        45
# 300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel    44
#                                                          ..
# 323.0HP 6.0L 8 Cylinder Engine Gasoline Fuel              1
# 405.0HP 4.2L 8 Cylinder Engine Gasoline Fuel              1
# 353.0HP 6.0L 8 Cylinder Engine Gasoline Fuel              1
# 275.0HP 4.8L 8 Cylinder Engine Gasoline Fuel              1
# 420.0HP 5.9L 12 Cylinder Engine Gasoline Fuel             1
# Name: count, Length: 1146, dtype: int64

# %%
# plot of top 5 engines
plt.figure(figsize=(10,5))
data['engine'].value_counts()[:5].plot(kind='bar')
plt.title('Plot of the Top 5 Engines')
plt.xlabel('Engine')
plt.ylabel('Count')
plt.show()

# %%
# transmission
data['transmission'].value_counts()
# Out:
# transmission
# A/T                                              1037
# 8-Speed A/T                                       406
# Transmission w/Dual Shift Mode                    398
# 6-Speed A/T                                       362
# 6-Speed M/T                                       248
#                                                  ...
# Automatic, 8-Spd PDK Dual-Clutch                    1
# Auto, 6-Spd w/CmdShft                               1
# Automatic, 8-Spd Sport w/Sport & Manual Modes       1
# CVT-F                                               1
# 8-Speed Manual                                      1
# Name: count, Length: 62, dtype: int64

# %%
# top 10 transmission type
plt.figure(figsize=(10,5))
data['transmission'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Count')
plt.show()

# %%
data.columns
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
# ext_col
data['ext_col'].value_counts()
# Out:
# ext_col
# Black                       905
# White                       816
# Gray                        496
# Silver                      374
# Blue                        349
#                            ...
# Anthracite Blue Metallic      1
# Moonlight Cloud               1
# Silver Mist                   1
# Cirrus Silver Metallic        1
# C / C                         1
# Name: count, Length: 319, dtype: int64

# %%
# top 10 ext col
plt.figure(figsize=(10,5))
data['ext_col'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Exterior Color')
plt.xlabel('Exterior Color')
plt.ylabel('Count')
plt.show()

# %%
# int_col
data['int_col'].value_counts()
# Out:
# int_col
# Black               2025
# Beige                538
# Gray                 472
# Brown                157
# –                    133
#                     ...
# Almond Beige           1
# Kyalami Orange         1
# Sakhir Orange          1
# Tan/Ebony              1
# Black / Graphite       1
# Name: count, Length: 156, dtype: int64

# %%
# top 10 int_col
plt.figure(figsize=(10,5))
data['int_col'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Interior Color')
plt.xlabel('Interior Color')
plt.ylabel('Count')
plt.show()

# %%
# accident
data['accident'].value_counts()
# Out:
# accident
# None reported                             2910
# At least 1 accident or damage reported     986
# Name: count, dtype: int64

# %%
#plot of the accident
plt.figure(figsize=(10,5))
sns.countplot(data['accident'])
plt.title('Plot of the Accident')
plt.xlabel('Accident')
plt.ylabel('Count')
plt.show()

# %%
# clean title
data['clean_title'].value_counts()
# Out:
# clean_title
# Yes    3413
# Name: count, dtype: int64

# %%
# price
data['price'].value_counts()
# Out:
# price
# $15,000    39
# $12,000    29
# $30,000    28
# $16,000    25
# $29,000    25
#            ..
# $43,666     1
# $70,250     1
# $80,140     1
# $31,750     1
# $90,998     1
# Name: count, Length: 1569, dtype: int64

# %%
# top 10 prices
plt.figure(figsize=(10,5))
data['price'].value_counts()[:10].plot(kind='bar')
plt.title('Plot of the Top 10 Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Group Analysis

# %%
# price
data['price'].head()
# Out:
# 0    $10,300
# 1    $38,005
# 2    $54,598
# 3    $15,500
# 4    $34,999
# Name: price, dtype: object

# %%
# cleaning the price column
data['price'] = data['price'].str.replace('$', '')
data['price'] = data['price'].str.replace(',', '')
data['price'] = data['price'].astype(float)

# %%
data['price'].head()
# Out:
# 0    10300.0
# 1    38005.0
# 2    54598.0
# 3    15500.0
# 4    34999.0
# Name: price, dtype: float64

# %%
#average Price of the top 10 brands
data.groupby('brand')['price'].mean().sort_values(ascending=False)[:10]
# Out:
# brand
# Bugatti        1.950995e+06
# Rolls-Royce    3.709927e+05
# Lamborghini    2.912338e+05
# Ferrari        2.437907e+05
# McLaren        2.134575e+05
# Maserati       1.405825e+05
# Bentley        1.375535e+05
# Aston          1.151996e+05
# Lucid          1.019663e+05
# Rivian         9.313818e+04
# Name: price, dtype: float64

# %%
# plot
plt.figure(figsize=(10,5))
data.groupby('brand')['price'].mean().sort_values(ascending=False)[:10].plot(kind='bar')
plt.title('Plot of the Average Price of the Top 10 Brands')
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.show()

# %%
# unique car brands in the dataset?
data['brand'].nunique()
# Out:
# 57

# %%
# 3. What is the average price of cars in the dataset?
average_price = data['price'].mean()
print("The average price of cars in the dataset is:", round(average_price,2))
# Out:
# The average price of cars in the dataset is: 44553.19

# %%
# range of model years available
data['model_year'].min()
data['model_year'].max()
model_year_range = data['model_year'].max() - data['model_year'].min()
print("The range of model years available is:", model_year_range)
# Out:
# The range of model years available is: 50

# %%
# cars have been involved in accidents?
accident_count = data['accident'].str.contains('At least 1', na=False).sum()
print("The number of cars involved in accidents is:", accident_count)
# Out:
# The number of cars involved in accidents is: 986

# %%
# percentage of cars have clean titles
clean_title_percentage = data['clean_title'].str.contains('Yes', na=False).mean() * 100
print("The percentage of cars with clean titles is:", round(clean_title_percentage,2),"%")
# Out:
# The percentage of cars with clean titles is: 85.13 %

# %%
#  How many cars have missing fuel type information?
missing_fuel_type = data['fuel_type'].isnull().sum()
print("The number of cars with missing fuel type information is:", missing_fuel_type)
# Out:
# The number of cars with missing fuel type information is: 170

# %%
# Which car brand has the highest average price?
average_price_by_brand = data.groupby('brand')['price'].mean()
brand_highest_avg_price = average_price_by_brand.idxmax()
print("The car brand with the highest average price is:", brand_highest_avg_price)
# Out:
# The car brand with the highest average price is: Bugatti

# %%
# the relationship between price and mileage
plt.figure(figsize=(10,5))
plt.scatter(data['milage'], data['price'])
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.title('Price vs. Mileage')
plt.show()

# %%
# car age
data['age'] = 2025 - data['model_year']

# %%
# oldest car
data.loc[data['age'].idxmax()]
# Out:
# brand                         Ford
# model                       Bronco
# model_year                    1974
# milage                   6,217 mi.
# fuel_type                        –
# engine                           –
# transmission                     –
# ext_col         Dark Gray Metallic
# int_col                          –
# accident             None reported
# clean_title                    Yes
# price                     115000.0
# age                             51
# Name: 855, dtype: object

# %%
#  average price of cars by fuel type?
data.groupby('fuel_type')['price'].mean()
# Out:
# fuel_type
# Diesel            48695.422414
# E85 Flex Fuel     22744.115108
# Gasoline          44538.525839
# Hybrid            51426.195876
# Plug-In Hybrid    45946.176471
# not supported     14000.000000
# –                 35745.888889
# Name: price, dtype: float64

# %%
# 18.  cars have automatic transmission?
data['transmission'].str.contains('Automatic', na=False).sum()
# Out:
# 715

# %%
#. What is the most expensive car in the dataset?
data[data['price'] == data['price'].max()]
# print("The most expensive car in the dataset is:", most_expensive_car)
# Out:
#         brand              model  model_year      milage fuel_type  \
# 693  Maserati  Quattroporte Base        2005  32,000 mi.  Gasoline
#
#                                            engine  \
# 693  394.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
#
#                        transmission ext_col int_col  \
# 693  Transmission w/Dual Shift Mode     Red   Beige
#
#                                    accident clean_title      price  age
# 693  At least 1 accident or damage reported         Yes  2954083.0   20

# %%
# 24.e average price of cars with clean titles?
data[data['clean_title'] == 'Yes']['price'].mean()
# Out:
# 41734.390272487544

# %%
#What is the relationship between car age and price?
plt.figure(figsize=(10,5))
plt.scatter(data['age'], data['price'])
plt.xlabel('Age')
plt.ylabel('Price')
plt.title('Age vs. Price')
plt.show()

# %% [markdown]
# # Preparing the data for predictive model

# %%
# finding duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# age               0
# dtype: int64

# %%
# removing missing values from the data
data.dropna(inplace=True)

# %%
# column data types
data.dtypes
# Out:
# brand            object
# model            object
# model_year        int64
# milage           object
# fuel_type        object
# engine           object
# transmission     object
# ext_col          object
# int_col          object
# accident         object
# clean_title      object
# price           float64
# age               int64
# dtype: object

# %%
data['milage']
# Out:
# 0        51,000 mi.
# 1        34,742 mi.
# 3        88,900 mi.
# 6        84,000 mi.
# 7       242,000 mi.
#            ...
# 4003     53,705 mi.
# 4004        714 mi.
# 4005     10,900 mi.
# 4007     33,000 mi.
# 4008     43,000 mi.
# Name: milage, Length: 3269, dtype: object

# %%
# working on the milage column
data['milage']  = data['milage'].str.replace(',', '')
data['milage']  = data['milage'].str.replace('mi.', '')
data['milage']  = data['milage'].astype(float)

# %%
data['milage'].value_counts()
# Out:
# milage
# 110000.0    16
# 45000.0     15
# 54000.0     12
# 120000.0    12
# 40000.0     12
#             ..
# 184421.0     1
# 137825.0     1
# 135140.0     1
# 33655.0      1
# 714.0        1
# Name: count, Length: 2194, dtype: int64

# %%
data.dtypes
# Out:
# brand            object
# model            object
# model_year        int64
# milage          float64
# fuel_type        object
# engine           object
# transmission     object
# ext_col          object
# int_col          object
# accident         object
# clean_title      object
# price           float64
# age               int64
# dtype: object

# %% [markdown]
# ## checking the number of unique values in the categorical columns

# %%
data['brand'].nunique()
# Out:
# 52

# %%
data['model'].nunique()
# Out:
# 1614

# %%
data['fuel_type'].nunique()
# Out:
# 7

# %%
data['engine'].nunique()
# Out:
# 963

# %%
data['transmission'].nunique()
# Out:
# 32

# %%
data['ext_col'].nunique()
# Out:
# 120

# %%
data['int_col'].nunique()
# Out:
# 74

# %%
data['accident'].nunique()
# Out:
# 2

# %%
data['clean_title'].nunique()
# Out:
# 1

# %% [markdown]
# # Feature Selection

# %%
#saved the cleaned_data
data.to_csv('cleaned_data.csv', index=False)

# %%
# droping the engine and model columns based on domain knowledge
data = data.drop(['model', 'engine'], axis=1)

# %%
data
# Out:
#               brand  model_year    milage      fuel_type  \
# 0              Ford        2013   51000.0  E85 Flex Fuel
# 1           Hyundai        2021   34742.0       Gasoline
# 3          INFINITI        2015   88900.0         Hybrid
# 6              Audi        2017   84000.0       Gasoline
# 7               BMW        2001  242000.0       Gasoline
# ...             ...         ...       ...            ...
# 4003  Mercedes-Benz        2018   53705.0       Gasoline
# 4004        Bentley        2023     714.0       Gasoline
# 4005           Audi        2022   10900.0       Gasoline
# 4007           Ford        2020   33000.0       Gasoline
# 4008            BMW        2020   43000.0       Gasoline
#
#                            transmission          ext_col  int_col  \
# 0                           6-Speed A/T            Black    Black
# 1                     8-Speed Automatic  Moonlight Cloud     Gray
# 3                           7-Speed A/T            Black    Black
# ...

# %%
# droping the clean_title column
data = data.drop(['clean_title'], axis=1)

# %%
# label encode the accident column
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['accident'] = le.fit_transform(data['accident'])

# %%
data
# Out:
#               brand  model_year    milage      fuel_type  \
# 0              Ford        2013   51000.0  E85 Flex Fuel
# 1           Hyundai        2021   34742.0       Gasoline
# 3          INFINITI        2015   88900.0         Hybrid
# 6              Audi        2017   84000.0       Gasoline
# 7               BMW        2001  242000.0       Gasoline
# ...             ...         ...       ...            ...
# 4003  Mercedes-Benz        2018   53705.0       Gasoline
# 4004        Bentley        2023     714.0       Gasoline
# 4005           Audi        2022   10900.0       Gasoline
# 4007           Ford        2020   33000.0       Gasoline
# 4008            BMW        2020   43000.0       Gasoline
#
#                            transmission          ext_col  int_col  accident  \
# 0                           6-Speed A/T            Black    Black         0
# 1                     8-Speed Automatic  Moonlight Cloud     Gray         0
# ...

# %% [markdown]
# ## Buinding a Predictive mode to select features

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
# Encode categorical columns
categorical_cols = ['brand', 'fuel_type', 'transmission', 'ext_col', 'int_col',]

#label encode
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %%
# target variable
y_target = data['price']

# %%
#drop the price
data = data.drop(['price'], axis=1)

# %%
data
# Out:
#       brand  model_year    milage  fuel_type  transmission  ext_col  int_col  \
# 0        14        2013   51000.0          1             7        8        1
# 1        19        2021   34742.0          2            20       69       32
# 3        20        2015   88900.0          3            13        8        1
# 6         3        2017   84000.0          2             7       14        1
# 7         4        2001  242000.0          2            24       47       33
# ...     ...         ...       ...        ...           ...      ...      ...
# 4003     34        2018   53705.0          2            24        8        1
# 4004      5        2023     714.0          2            21       20       34
# 4005      3        2022   10900.0          2            30        8        1
# 4007     14        2020   33000.0          2            24       14        1
# 4008      4        2020   43000.0          2            24       46        9
#
#       accident  age
# 0            0   12
# ...

# %%
X_train
# Out:
#       accident  age  int_col  brand  mileage_per_year    milage
# 2198         1   11        1     48       8363.636364   92000.0
# 1064         1    6        1     23      10443.333333   62660.0
# 3646         0   10       32     50       3900.000000   39000.0
# 1350         1    4       32      3       4525.000000   18100.0
# 1353         1    2       32     48        162.500000     325.0
# ...        ...  ...      ...    ...               ...       ...
# 1436         0    8       41      7      17388.125000  139105.0
# 1474         1   17        1      0      10848.294118  184421.0
# 1674         1   10        6     26      12400.000000  124000.0
# 1156         1   19        4     40       1635.526316   31075.0
# 3902         0   12        1      4       5583.333333   67000.0
#
# [2615 rows x 6 columns]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, y_target, test_size=0.2, random_state=42)

# %%
y_test
# Out:
# 3796     28900.0
# 180     417500.0
# 561      46599.0
# 278      27900.0
# 3622     49990.0
#           ...
# 2650     13000.0
# 3854     79900.0
# 1097      9500.0
# 644      18999.0
# 3173     22888.0
# Name: price, Length: 654, dtype: float64

# %%
# Train the linear regression model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = lr_model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Square Error: {rmse}")
# Out:
# Mean Squared Error: 14231127010.004772
# Root Mean Square Error: 119294.2874156377

# %%
coefficients = pd.DataFrame({'Feature': data.columns, 'Coefficient': lr_model.coef_})
print(coefficients.sort_values(by='Coefficient', ascending=True))
# Out:
#         Feature  Coefficient
# 3     fuel_type -1754.341335
# 8           age  -319.873701
# 4  transmission   -23.273500
# 2        milage    -0.389758
# 5       ext_col    25.121408
# 0         brand   166.617973
# 6       int_col   237.799298
# 1    model_year   319.873701
# 7      accident  7874.690069

# %% [markdown]
# # Feature engineering
# * columns to keep =[accident , age ,int_col ,brand,milage]

# %%
data['mileage_per_year'] = data['milage'] / data['age']

# %%
columns_to_keep = ['accident', 'age', 'int_col', 'brand', 'mileage_per_year','milage']
data = data[columns_to_keep]

# %% [markdown]
# # Predictive Model

# %%
# splting the data
X_train, X_test, y_train, y_test = train_test_split(data, y_target, test_size=0.2, random_state=42)

# %%
# Train the linear regression model for the second time
lr_model2 = LinearRegression()
lr_model2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluation

# %%
# Evaluate the model
mse_2 = mean_squared_error(y_test, y_pred)
rmse_2 = np.sqrt(mse_2)

print(f"Mean Squared Error: {mse_2}")
print(f"Root Mean Square Error: {rmse_2}")
# Out:
# Mean Squared Error: 14231127010.004772
# Root Mean Square Error: 119294.2874156377

# %%
coefficients = pd.DataFrame({'Feature': data.columns, 'Coefficient': lr_model2.coef_})
print(coefficients.sort_values(by='Coefficient', ascending=True))
# Out:
#             Feature  Coefficient
# 1               age -2219.946793
# 4  mileage_per_year    -3.313678
# 5            milage    -0.105087
# 3             brand   145.610842
# 2           int_col   241.566362
# 0          accident  7965.026317

# %% [markdown]
# # Visualization

# %%
# visualization of ypred vs y_test with different colors
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction Line')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Prices vs Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# sorting the values to  organize them to plot a more readable line plot
#
sorted_indices = np.argsort(y_test)
y_test_sorted = np.array(y_test)[sorted_indices]
y_pred_sorted = np.array(y_pred)[sorted_indices]

plt.figure(figsize=(12, 6))
plt.plot(y_test_sorted, label='Actual Prices', color='blue', linewidth=2)
plt.plot(y_pred_sorted, label='Predicted Prices', color='orange', linestyle='--', linewidth=2)

# Add labels, title, and legend
plt.xlabel('Data Points (Sorted by Actual Prices)')
plt.ylabel('Prices')
plt.title('Comparison of Actual Prices vs Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
